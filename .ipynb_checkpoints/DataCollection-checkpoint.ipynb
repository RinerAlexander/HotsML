# %%
import requests
import json
from pprint import pprint
import re

# %%
url = "http://hotsapi.net/api/v1/replays?min_id=30000000&existing=true&with_players=true"

# %%
raw_data=requests.get(url).json()

# %%
pprint(raw_data[4])
# Out:
# {'bans': [['D.Va', "Kael'thas", 'Brightwing'],
#           ['Tassadar', 'Gazlowe', 'Anduin']],
#  'created_at': '2020-11-20 02:33:31',
#  'deleted': False,
#  'filename': '4adfc0bf-e2ee-65e2-b759-9650d396db7b',
#  'fingerprint': '4adfc0bf-e2ee-65e2-b759-9650d396db7b',
#  'game_date': '2020-11-20 02:34:54',
#  'game_length': 1238,
#  'game_map': 'Cursed Hollow',
#  'game_type': 'StormLeague',
#  'game_version': '2.52.2.82624',
#  'id': 30233400,
#  'parsed_id': 25796241,
#  'players': {'0': {'battletag': 'wowcolico#1170',
#                    'blizz_id': 996178,
#                    'hero': 'Raynor',
#                    'hero_level': 20,
#                    'party': 0,
#                    'score': {'assists': 7,
#                              'clutch_heals_performed': 0,
#                              'creep_damage': 4162,
#                              'damage_soaked': 33037,
#                              'damage_taken': 41477,
#                              'deaths': 3,
#                              'escapes_performed': 3,
#                              'experience_contribution': 7258,
#                              'healing': None,
#                              'hero_damage': 52435,
#                              'highest_kill_streak': 4,
#                              'kills': 2,
#                              'level': 20,
#                              'merc_camp_captures': 1,
#                              'meta_experience': 74830,
#                              'minion_damage': 14731,
#                              'multikill': 1,
#                              'outnumbered_deaths': 0,
#                              'physical_damage': 86850,
#                              'protection_given_to_allies': 0,
#                              'self_healing': 7649,
#                              'siege_damage': 39889,
#                              'spell_damage': 20846,
#                              'structure_damage': 2799,
#                              'summon_damage': 6009,
#                              'takedowns': 9,
#                              'teamfight_damage_taken': 17853,
#                              'teamfight_escapes_performed': 0,
#                              'teamfight_healing_done': 0,
#                              'teamfight_hero_damage': 18848,
#                              'time_cc_enemy_heroes': 24,
#                              'time_rooting_enemy_heroes': 0,
#                              'time_silencing_enemy_heroes': 0,
#                              'time_spent_dead': 150,
#                              'time_stunning_enemy_heroes': 0,
#                              'town_kills': 0,
#                              'vengeances_performed': 0,
#                              'watch_tower_captures': 0},
#                    'silenced': False,
#                    'talents': {'1': 'RaynorVeteranMarksman',
#                                '10': 'RaynorHeroicAbilityHyperion',
#                                '13': 'RaynorInspireGiddyUp',
#                                '16': 'RaynorBountyHunter',
#                                '4': 'RaynorMasteryFightorFlightAdrenalineRush',
#                                '7': 'RaynorGiveEmSomePepperUnstableCompound'},
#                    'team': 0,
#                    'winner': False},
#              '1': {'battletag': 'Rökkur#1384',
#                    'blizz_id': 1051782,
#                    'hero': 'Alexstrasza',
#                    'hero_level': 11,
#                    'party': 0,
#                    'score': {'assists': 14,
#                              'clutch_heals_performed': 0,
#                              'creep_damage': 15650,
#                              'damage_soaked': 20794,
#                              'damage_taken': 31554,
#                              'deaths': 3,
#                              'escapes_performed': 0,
#                              'experience_contribution': 7289,
#                              'healing': 62161,
#                              'hero_damage': 18008,
#                              'highest_kill_streak': 10,
#                              'kills': 0,
#                              'level': 22,
#                              'merc_camp_captures': 6,
#                              'meta_experience': 91177,
#                              'minion_damage': 15500,
#                              'multikill': 4,
#                              'outnumbered_deaths': 2,
#                              'physical_damage': 22196,
#                              'protection_given_to_allies': 0,
#                              'self_healing': 2420,
#                              'siege_damage': 21979,
#                              'spell_damage': 31471,
#                              'structure_damage': 3108,
#                              'summon_damage': 847,
#                              'takedowns': 14,
#                              'teamfight_damage_taken': 21397,
#                              'teamfight_escapes_performed': 0,
#                              'teamfight_healing_done': 6733,
#                              'teamfight_hero_damage': 8229,
#                              'time_cc_enemy_heroes': 128,
#                              'time_rooting_enemy_heroes': 0,
#                              'time_silencing_enemy_heroes': 0,
#                              'time_spent_dead': 177,
#                              'time_stunning_enemy_heroes': 0,
#                              'town_kills': 0,
#                              'vengeances_performed': 0,
#                              'watch_tower_captures': 0},
#                    'silenced': False,
#                    'talents': {'1': 'AlexstraszaCircleOfLifeAbundance',
#                                '10': 'AlexstraszaLifebinder',
#                                '13': 'AlexstraszaDragonScales',
#                                '16': 'AlexstraszaOverprotectiveAbundance',
#                                '20': 'AlexstraszaRitualOfLife',
#                                '4': 'AlexstraszaSurgeOfVitalityAbundance',
#                                '7': 'AlexstraszaVerdantFlourishAbundance'},
#                    'team': 1,
#                    'winner': True},
#              '2': {'battletag': 'BigLebanon#1551',
#                    'blizz_id': 1131247,
#                    'hero': 'Tychus',
#                    'hero_level': 20,
#                    'party': 0,
#                    'score': {'assists': 10,
#                              'clutch_heals_performed': 0,
#                              'creep_damage': 35709,
#                              'damage_soaked': 35858,
#                              'damage_taken': 43793,
#                              'deaths': 3,
#                              'escapes_performed': 0,
#                              'experience_contribution': 8946,
#                              'healing': None,
#                              'hero_damage': 77447,
#                              'highest_kill_streak': 14,
#                              'kills': 9,
#                              'level': 22,
#                              'merc_camp_captures': 4,
#                              'meta_experience': 91177,
#                              'minion_damage': 7948,
#                              'multikill': 4,
#                              'outnumbered_deaths': 2,
#                              'physical_damage': 50941,
#                              'protection_given_to_allies': 0,
#                              'self_healing': 8756,
#                              'siege_damage': 23324,
#                              'spell_damage': 80956,
#                              'structure_damage': 11210,
#                              'summon_damage': 4166,
#                              'takedowns': 19,
#                              'teamfight_damage_taken': 23632,
#                              'teamfight_escapes_performed': 0,
#                              'teamfight_healing_done': 0,
#                              'teamfight_hero_damage': 31438,
#                              'time_cc_enemy_heroes': 11912,
#                              'time_rooting_enemy_heroes': 0,
#                              'time_silencing_enemy_heroes': 0,
#                              'time_spent_dead': 68,
#                              'time_stunning_enemy_heroes': 0,
#                              'town_kills': 0,
#                              'vengeances_performed': 3,
#                              'watch_tower_captures': 1},
#                    'silenced': False,
#                    'talents': {'1': 'TychusPressTheAdvantage',
#                                '10': 'TychusHeroicAbilityDrakkenLaserDrill',
#                                '13': 'TychusThatsTheStuff',
#                                '16': 'TychusMasteryFragGrenadeTitanGrenade',
#                                '20': 'TychusRunAndGunBobAndWeave',
#                                '4': 'TychusInTheRhythm',
#                                '7': 'TychusCombatTactician'},
#                    'team': 1,
#                    'winner': True},
#              '3': {'battletag': 'SupremoXX#1881',
#                    'blizz_id': 1715427,
#                    'hero': None,
#                    'hero_level': 8,
#                    'party': 0,
#                    'score': {'assists': 14,
#                              'clutch_heals_performed': 0,
#                              'creep_damage': 7027,
#                              'damage_soaked': 37204,
#                              'damage_taken': 37204,
#                              'deaths': 0,
#                              'escapes_performed': 1,
#                              'experience_contribution': 15481,
#                              'healing': None,
#                              'hero_damage': 77015,
#                              'highest_kill_streak': 19,
#                              'kills': 5,
#                              'level': 22,
#                              'merc_camp_captures': 2,
#                              'meta_experience': 91177,
#                              'minion_damage': 52041,
#                              'multikill': 5,
#                              'outnumbered_deaths': 0,
#                              'physical_damage': 23292,
#                              'protection_given_to_allies': 0,
#                              'self_healing': 9910,
#                              'siege_damage': 77608,
#                              'spell_damage': 131973,
#                              'structure_damage': 19789,
#                              'summon_damage': 5778,
#                              'takedowns': 19,
#                              'teamfight_damage_taken': 21908,
#                              'teamfight_escapes_performed': 0,
#                              'teamfight_healing_done': 0,
#                              'teamfight_hero_damage': 36501,
#                              'time_cc_enemy_heroes': 299,
#                              'time_rooting_enemy_heroes': 0,
#                              'time_silencing_enemy_heroes': 0,
#                              'time_spent_dead': 0,
#                              'time_stunning_enemy_heroes': 22,
#                              'town_kills': 0,
#                              'vengeances_performed': 0,
#                              'watch_tower_captures': 1},
#                    'silenced': False,
#                    'talents': {'1': 'DeathwingDraconicMight',
#                                '10': 'DeathwingBurnBeneathMyShadow',
#                                '13': 'DeathwingWickedInferno',
#                                '16': 'DeathwingConflagration',
#                                '20': 'DeathwingStoodInTheFire',
#                                '4': 'DeathwingInfernus',
#                                '7': 'DeathwingSkyfall'},
#                    'team': 1,
#                    'winner': True},
#              '4': {'battletag': 'Anjuna#11248',
#                    'blizz_id': 1866194,
#                    'hero': 'Alarak',
#                    'hero_level': 18,
#                    'party': 0,
#                    'score': {'assists': 3,
#                              'clutch_heals_performed': 0,
#                              'creep_damage': 0,
#                              'damage_soaked': 40296,
#                              'damage_taken': 58241,
#                              'deaths': 5,
#                              'escapes_performed': 2,
#                              'experience_contribution': 10041,
#                              'healing': None,
#                              'hero_damage': 39180,
#                              'highest_kill_streak': 2,
#                              'kills': 5,
#                              'level': 20,
#                              'merc_camp_captures': 0,
#                              'meta_experience': 74830,
#                              'minion_damage': 46603,
#                              'multikill': 1,
#                              'outnumbered_deaths': 2,
#                              'physical_damage': 45180,
#                              'protection_given_to_allies': 0,
#                              'self_healing': 10120,
#                              'siege_damage': 62692,
#                              'spell_damage': 53339,
#                              'structure_damage': 2027,
#                              'summon_damage': 2892,
#                              'takedowns': 8,
#                              'teamfight_damage_taken': 26660,
#                              'teamfight_escapes_performed': 0,
#                              'teamfight_healing_done': 0,
#                              'teamfight_hero_damage': 21365,
#                              'time_cc_enemy_heroes': 30,
#                              'time_rooting_enemy_heroes': 0,
#                              'time_silencing_enemy_heroes': 21,
#                              'time_spent_dead': 225,
#                              'time_stunning_enemy_heroes': 0,
#                              'town_kills': 1,
#                              'vengeances_performed': 0,
#                              'watch_tower_captures': 1},
#                    'silenced': False,
#                    'talents': {'1': 'AlarakOverwhelmingPowerDiscordStrike',
#                                '10': 'AlarakHeroicAbilityCounterStrike',
#                                '13': 'AlarakBladeoftheHighlord',
#                                '16': 'AlarakLethalOnslaughtDiscordStrike',
#                                '20': 'AlarakDeadlyChargeSecondHeroic',
#                                '4': 'AlarakChaosReigns',
#                                '7': 'AlarakHinderedMotion'},
#                    'team': 0,
#                    'winner': False},
#              '5': {'battletag': 'MineralBunny#1571',
#                    'blizz_id': 2015277,
#                    'hero': None,
#                    'hero_level': 20,
#                    'party': 0,
#                    'score': {'assists': 14,
#                              'clutch_heals_performed': 0,
#                              'creep_damage': 17152,
#                              'damage_soaked': 69817,
#                              'damage_taken': 78285,
#                              'deaths': 2,
#                              'escapes_performed': 1,
#                              'experience_contribution': 8663,
#                              'healing': None,
#                              'hero_damage': 37938,
#                              'highest_kill_streak': 9,
#                              'kills': 4,
#                              'level': 22,
#                              'merc_camp_captures': 3,
#                              'meta_experience': 91177,
#                              'minion_damage': 25592,
#                              'multikill': 5,
#                              'outnumbered_deaths': 1,
#                              'physical_damage': 19655,
#                              'protection_given_to_allies': 0,
#                              'self_healing': 16208,
#                              'siege_damage': 38669,
#                              'spell_damage': 71535,
#                              'structure_damage': 8985,
#                              'summon_damage': 3990,
#                              'takedowns': 18,
#                              'teamfight_damage_taken': 52128,
#                              'teamfight_escapes_performed': 0,
#                              'teamfight_healing_done': 0,
#                              'teamfight_hero_damage': 22105,
#                              'time_cc_enemy_heroes': 650,
#                              'time_rooting_enemy_heroes': 0,
#                              'time_silencing_enemy_heroes': 0,
#                              'time_spent_dead': 69,
#                              'time_stunning_enemy_heroes': 25,
#                              'town_kills': 0,
#                              'vengeances_performed': 0,
#                              'watch_tower_captures': 7},
#                    'silenced': False,
#                    'talents': {'1': 'MeiOWIceStorm',
#                                '10': 'MeiOWAvalanche',
#                                '13': 'MeiOWPolarVortex',
#                                '16': 'MeiOWFreshPowder',
#                                '20': 'MeiOWTheBigOne',
#                                '4': 'MeiOWColdFront',
#                                '7': 'MeiOWInduceHibernation'},
#                    'team': 1,
#                    'winner': True},
#              '6': {'battletag': 'Blurple#1311',
#                    'blizz_id': 2123539,
#                    'hero': 'Johanna',
#                    'hero_level': 20,
#                    'party': 0,
#                    'score': {'assists': 8,
#                              'clutch_heals_performed': 0,
#                              'creep_damage': 9968,
#                              'damage_soaked': 54588,
#                              'damage_taken': 71645,
#                              'deaths': 4,
#                              'escapes_performed': 2,
#                              'experience_contribution': 7902,
#                              'healing': None,
#                              'hero_damage': 28743,
#                              'highest_kill_streak': 3,
#                              'kills': 1,
#                              'level': 20,
#                              'merc_camp_captures': 1,
#                              'meta_experience': 74830,
#                              'minion_damage': 46547,
#                              'multikill': 1,
#                              'outnumbered_deaths': 2,
#                              'physical_damage': 20345,
#                              'protection_given_to_allies': 0,
#                              'self_healing': 28976,
#                              'siege_damage': 61193,
#                              'spell_damage': 78774,
#                              'structure_damage': 1432,
#                              'summon_damage': 4381,
#                              'takedowns': 9,
#                              'teamfight_damage_taken': 55975,
#                              'teamfight_escapes_performed': 0,
#                              'teamfight_healing_done': 0,
#                              'teamfight_hero_damage': 21093,
#                              'time_cc_enemy_heroes': 51,
#                              'time_rooting_enemy_heroes': 0,
#                              'time_silencing_enemy_heroes': 0,
#                              'time_spent_dead': 134,
#                              'time_stunning_enemy_heroes': 15,
#                              'town_kills': 0,
#                              'vengeances_performed': 0,
#                              'watch_tower_captures': 0},
#                    'silenced': False,
#                    'talents': {'1': 'CrusaderMasteryLawsOfHope',
#                                '10': 'CrusaderHeroicAbilityBlessedShield',
#                                '13': 'CrusaderHolyFury',
#                                '16': 'CrusaderMasteryShieldGlareHolyRenewal',
#                                '4': 'CrusaderMasteryShieldGlareSinsExposed',
#                                '7': 'CrusaderZealousGlare'},
#                    'team': 0,
#                    'winner': False},
#              '7': {'battletag': 'Bartholamew#1173',
#                    'blizz_id': 2165151,
#                    'hero': 'Stukov',
#                    'hero_level': 20,
#                    'party': 0,
#                    'score': {'assists': 8,
#                              'clutch_heals_performed': 2,
#                              'creep_damage': 16063,
#                              'damage_soaked': 34159,
#                              'damage_taken': 53199,
#                              'deaths': 6,
#                              'escapes_performed': 3,
#                              'experience_contribution': 4073,
#                              'healing': 64185,
#                              'hero_damage': 32294,
#                              'highest_kill_streak': 3,
#                              'kills': 1,
#                              'level': 20,
#                              'merc_camp_captures': 2,
#                              'meta_experience': 74830,
#                              'minion_damage': 9775,
#                              'multikill': 1,
#                              'outnumbered_deaths': 2,
#                              'physical_damage': 36691,
#                              'protection_given_to_allies': 0,
#                              'self_healing': 0,
#                              'siege_damage': 14909,
#                              'spell_damage': 26245,
#                              'structure_damage': 0,
#                              'summon_damage': 1811,
#                              'takedowns': 9,
#                              'teamfight_damage_taken': 38837,
#                              'teamfight_escapes_performed': 0,
#                              'teamfight_healing_done': 14051,
#                              'teamfight_hero_damage': 21519,
#                              'time_cc_enemy_heroes': 748,
#                              'time_rooting_enemy_heroes': 0,
#                              'time_silencing_enemy_heroes': 12,
#                              'time_spent_dead': 228,
#                              'time_stunning_enemy_heroes': 2,
#                              'town_kills': 0,
#                              'vengeances_performed': 0,
#                              'watch_tower_captures': 4},
#                    'silenced': False,
#                    'talents': {'1': 'StukovWeightedPustuleReactiveBallistospores',
#                                '10': 'StukovHeroicAbilityMassiveShove',
#                                '13': 'StukovPoppinPustules',
#                                '16': 'StukovUniversalCarrier',
#                                '20': 'StukovTopOff',
#                                '4': 'StukovBioticArmor',
#                                '7': 'StukovTargetedExcision'},
#                    'team': 0,
#                    'winner': False},
#              '8': {'battletag': 'RamiroLopez#1626',
#                    'blizz_id': 8377409,
#                    'hero': 'Nazeebo',
#                    'hero_level': 4,
#                    'party': 0,
#                    'score': {'assists': 9,
#                              'clutch_heals_performed': 0,
#                              'creep_damage': 52183,
#                              'damage_soaked': 21738,
#                              'damage_taken': 26951,
#                              'deaths': 1,
#                              'escapes_performed': 1,
#                              'experience_contribution': 16674,
#                              'healing': None,
#                              'hero_damage': 35180,
#                              'highest_kill_streak': 12,
#                              'kills': 3,
#                              'level': 22,
#                              'merc_camp_captures': 6,
#                              'meta_experience': 91177,
#                              'minion_damage': 75169,
#                              'multikill': 2,
#                              'outnumbered_deaths': 1,
#                              'physical_damage': 32444,
#                              'protection_given_to_allies': 0,
#                              'self_healing': 0,
#                              'siege_damage': 109043,
#                              'spell_damage': 159023,
#                              'structure_damage': 21205,
#                              'summon_damage': 2689,
#                              'takedowns': 12,
#                              'teamfight_damage_taken': 9506,
#                              'teamfight_escapes_performed': 0,
#                              'teamfight_healing_done': 0,
#                              'teamfight_hero_damage': 7650,
#                              'time_cc_enemy_heroes': 6,
#                              'time_rooting_enemy_heroes': 0,
#                              'time_silencing_enemy_heroes': 0,
#                              'time_spent_dead': 65,
#                              'time_stunning_enemy_heroes': 0,
#                              'town_kills': 2,
#                              'vengeances_performed': 0,
#                              'watch_tower_captures': 0},
#                    'silenced': False,
#                    'talents': {'1': 'WitchDoctorThingOfTheDeep',
#                                '10': 'WitchDoctorHeroicAbilityRavenousSpirits',
#                                '13': 'GenericTalentIceBlock',
#                                '16': 'WitchDoctorRingOfPoison',
#                                '20': 'WitchDoctorVileInfection',
#                                '4': 'WitchDoctorBigVoodoo',
#                                '7': 'WitchDoctorDeadRush'},
#                    'team': 1,
#                    'winner': True},
#              '9': {'battletag': 'Snake#13674',
#                    'blizz_id': 9202796,
#                    'hero': 'Azmodan',
#                    'hero_level': 20,
#                    'party': 0,
#                    'score': {'assists': 7,
#                              'clutch_heals_performed': 0,
#                              'creep_damage': 9467,
#                              'damage_soaked': 21971,
#                              'damage_taken': 36964,
#                              'deaths': 3,
#                              'escapes_performed': 1,
#                              'experience_contribution': 15792,
#                              'healing': None,
#                              'hero_damage': 40926,
#                              'highest_kill_streak': 5,
#                              'kills': 0,
#                              'level': 20,
#                              'merc_camp_captures': 2,
#                              'meta_experience': 74830,
#                              'minion_damage': 99395,
#                              'multikill': 1,
#                              'outnumbered_deaths': 2,
#                              'physical_damage': 12910,
#                              'protection_given_to_allies': 0,
#                              'self_healing': 0,
#                              'siege_damage': 121313,
#                              'spell_damage': 157386,
#                              'structure_damage': 2400,
#                              'summon_damage': 4080,
#                              'takedowns': 7,
#                              'teamfight_damage_taken': 20538,
#                              'teamfight_escapes_performed': 0,
#                              'teamfight_healing_done': 0,
#                              'teamfight_hero_damage': 11300,
#                              'time_cc_enemy_heroes': 36,
#                              'time_rooting_enemy_heroes': 0,
#                              'time_silencing_enemy_heroes': 0,
#                              'time_spent_dead': 168,
#                              'time_stunning_enemy_heroes': 0,
#                              'town_kills': 0,
#                              'vengeances_performed': 0,
#                              'watch_tower_captures': 0},
#                    'silenced': False,
#                    'talents': {'1': 'AzmodanGluttony',
#                                '10': 'AzmodanTideOfSin',
#                                '13': 'AzmodanBrutishVanguard',
#                                '16': 'AzmodanTotalAnnihilation',
#                                '20': 'AzmodanPride',
#                                '4': 'AzmodanHellforgedArmor',
#                                '7': 'AzmodanArtOfChaos'},
#                    'team': 0,
#                    'winner': False}},
#  'processed': True,
#  'region': 1,
#  'size': 1537318,
#  'teams': [{'creep_xp': 1381,
#             'first_pick': True,
#             'hero_xp': 9222,
#             'minion_xp': 34214,
#             'structure_xp': 500,
#             'team_level': 20,
#             'total_xp': 74829,
#             'trickle_xp': 29512,
#             'winner': False},
#            {'creep_xp': 4590,
#             'first_pick': False,
#             'hero_xp': 18876,
#             'minion_xp': 30886,
#             'structure_xp': 3150,
#             'team_level': 22,
#             'total_xp': 91176,
#             'trickle_xp': 33674,
#             'winner': True}],
#  'updated_at': '2020-11-25 03:18:35',
#  'url': 'http://hotsapi.s3-website-eu-west-1.amazonaws.com/4adfc0bf-e2ee-65e2-b759-9650d396db7b.StormReplay'}

# %%
data=[]
for game in raw_data:
    first_team=[]
    second_team=[]
    for player in game["players"]:
        name=game["players"][player]["hero"]
        
        #Newer hero's don't have names but we are able to pull the name from the 
        #talents
        if name == None:
            name = game["players"][player]["talents"]["1"]
            name=re.sub( r"([A-Z])", r" \1", name).split()[0]
            
        if game["players"][player]["team"]==0:
            first_team.append(name)
        else:
            second_team.append(name)
            
    game_data={
        "first":first_team,
        "second":second_team,
        "map":game["game_map"],
        "type":game["game_type"],
        "first_won":game["teams"][0]["winner"]
    }
    data.append(game_data)

# %%
pprint(data)
# Out:
# [{'first': ['Sylvanas', 'Johanna', 'Rehgar', 'Deathwing', 'Raynor'],
#   'first_won': True,
#   'map': 'Sky Temple',
#   'second': ['Li-Ming', 'D.Va', 'Valeera', 'Muradin', 'Kharazim'],
#   'type': 'StormLeague'},
#  {'first': ['Nazeebo', 'Ana', 'Valla', 'Johanna', 'Imperius'],
#   'first_won': True,
#   'map': 'Volskaya Foundry',
#   'second': ['Muradin', 'Raynor', 'Artanis', "Gul'dan", 'Auriel'],
#   'type': 'StormLeague'},
#  {'first': ['Orphea', 'Greymane', 'Malfurion', 'Muradin', 'Malthael'],
#   'first_won': True,
#   'map': 'Volskaya Foundry',
#   'second': ['Diablo', 'Tychus', 'Mephisto', 'Whitemane', 'Yrel'],
#   'type': 'StormLeague'},
#  {'first': ['Lúcio', 'Qhira', 'E.T.C.', 'Li-Ming', 'Sonya'],
#   'first_won': False,
#   'map': 'Towers of Doom',
#   'second': ['Hanzo', 'Johanna', 'Nova', 'Leoric', 'Ana'],
#   'type': 'StormLeague'},
#  {'first': ['Alarak', 'Azmodan', 'Stukov', 'Johanna', 'Raynor'],
#   'first_won': False,
#   'map': 'Cursed Hollow',
#   'second': ['Mei', 'Nazeebo', 'Deathwing', 'Alexstrasza', 'Tychus'],
#   'type': 'StormLeague'},
#  {'first': ['Gazlowe', 'Arthas', 'D.Va', 'Li Li', 'Valla'],
#   'first_won': False,
#   'map': 'Towers of Doom',
#   'second': ['Brightwing', 'Johanna', 'Leoric', 'Orphea', 'Tychus'],
#   'type': 'StormLeague'},
#  {'first': ['Samuro', 'Diablo', 'Hanzo', 'Sgt. Hammer', 'Uther'],
#   'first_won': True,
#   'map': 'Sky Temple',
#   'second': ['Lunara', 'Sonya', 'Ana', 'Muradin', 'Chromie'],
#   'type': 'StormLeague'},
#  {'first': ['Brightwing', "Anub'arak", 'Artanis', 'Li Li', "Kael'thas"],
#   'first_won': False,
#   'map': 'Garden of Terror',
#   'second': ['Imperius', 'Rehgar', 'Greymane', 'Xul', 'Tassadar'],
#   'type': 'StormLeague'},
#  {'first': ['Azmodan', 'Stukov', 'Samuro', 'Blaze', 'Deathwing'],
#   'first_won': True,
#   'map': 'Tomb of the Spider Queen',
#   'second': ['E.T.C.', 'Tychus', 'Li-Ming', 'Qhira', 'Brightwing'],
#   'type': 'StormLeague'},
#  {'first': ["Kael'thas", 'Leoric', 'Garrosh', 'Lunara', 'Lúcio'],
#   'first_won': False,
#   'map': 'Braxis Holdout',
#   'second': ['Rexxar', 'Diablo', 'Stukov', 'Qhira', 'Tassadar'],
#   'type': 'StormLeague'},
#  {'first': ['Tassadar', 'E.T.C.', 'Kerrigan', 'Uther', 'Imperius'],
#   'first_won': True,
#   'map': 'Alterac Pass',
#   'second': ['Cassia', 'Deckard', 'Diablo', 'Sylvanas', 'Thrall'],
#   'type': 'StormLeague'},
#  {'first': ['Leoric', 'Tychus', 'Fenix', 'Mei', 'Whitemane'],
#   'first_won': True,
#   'map': 'Garden of Terror',
#   'second': ['E.T.C.', 'Brightwing', 'Varian', "Gul'dan", 'Raynor'],
#   'type': 'StormLeague'},
#  {'first': ['Gazlowe', 'Lúcio', 'Arthas', "Gul'dan", 'Samuro'],
#   'first_won': True,
#   'map': 'Sky Temple',
#   'second': ['Varian', 'Brightwing', 'Li-Ming', 'Maiev', 'Muradin'],
#   'type': 'StormLeague'},
#  {'first': ['Fenix', 'Tassadar', 'Auriel', "Anub'arak", 'Imperius'],
#   'first_won': True,
#   'map': 'Volskaya Foundry',
#   'second': ['Mephisto', 'Tyrande', 'Varian', 'Hanzo', 'Deathwing'],
#   'type': 'StormLeague'},
#  {'first': ['D.Va', 'Muradin', 'Azmodan', 'Whitemane', 'Jaina'],
#   'first_won': False,
#   'map': 'Infernal Shrines',
#   'second': ['Li-Ming', 'E.T.C.', 'Kharazim', 'Murky', 'Artanis'],
#   'type': 'StormLeague'},
#  {'first': ['Brightwing', "Gul'dan", 'Thrall', 'Gazlowe', 'Muradin'],
#   'first_won': True,
#   'map': 'Garden of Terror',
#   'second': ['Raynor', 'Stukov', 'Artanis', 'Chen', 'Malthael'],
#   'type': 'StormLeague'},
#  {'first': ['Stitches', 'Nazeebo', 'Lunara', 'Auriel', 'Illidan'],
#   'first_won': True,
#   'map': 'Garden of Terror',
#   'second': ['Lúcio', 'Blaze', 'Valla', 'Jaina', 'Varian'],
#   'type': 'StormLeague'},
#  {'first': ['Sylvanas', 'Zarya', 'Valla', 'Tyrael', 'Rehgar'],
#   'first_won': True,
#   'map': 'Hanamura Temple',
#   'second': ['Imperius', 'Falstad', 'Tyrande', 'Raynor', 'Varian'],
#   'type': 'StormLeague'},
#  {'first': ['Li-Ming', 'Stitches', 'Raynor', 'Rehgar', 'Arthas'],
#   'first_won': True,
#   'map': 'Braxis Holdout',
#   'second': ["Mal'Ganis", 'Greymane', 'Stukov', 'Tychus', 'Muradin'],
#   'type': 'StormLeague'},
#  {'first': ['Tassadar', 'Johanna', 'Anduin', 'Greymane', 'Xul'],
#   'first_won': True,
#   'map': 'Tomb of the Spider Queen',
#   'second': ['Cassia', 'Gazlowe', 'Ana', 'Nazeebo', 'Imperius'],
#   'type': 'StormLeague'},
#  {'first': ['Tychus', 'Diablo', 'Brightwing', 'Mephisto', 'Malthael'],
#   'first_won': True,
#   'map': 'Cursed Hollow',
#   'second': ['Junkrat', 'Rexxar', 'Alexstrasza', 'E.T.C.', 'Greymane'],
#   'type': 'StormLeague'},
#  {'first': ['Li-Ming', 'E.T.C.', 'Li Li', 'Raynor', 'Illidan'],
#   'first_won': True,
#   'map': 'Battlefield of Eternity',
#   'second': ['Artanis', 'Malfurion', 'Valla', 'Alarak', "Anub'arak"],
#   'type': 'StormLeague'},
#  {'first': ['Varian', 'Mephisto', 'Brightwing', 'Murky', 'Arthas'],
#   'first_won': True,
#   'map': 'Hanamura Temple',
#   'second': ['Nazeebo', 'Alarak', 'Xul', 'Stukov', 'Johanna'],
#   'type': 'StormLeague'},
#  {'first': ["Kael'thas", 'Diablo', 'Sonya', 'Raynor', 'Malfurion'],
#   'first_won': False,
#   'map': 'Tomb of the Spider Queen',
#   'second': ['Hanzo', "Kel'Thuzad", 'Thrall', 'Stitches', 'Brightwing'],
#   'type': 'StormLeague'},
#  {'first': ['Tassadar', 'Brightwing', 'Nazeebo', 'Johanna', 'Kerrigan'],
#   'first_won': True,
#   'map': 'Alterac Pass',
#   'second': ['Jaina', 'Muradin', 'Malthael', 'Genji', 'Lúcio'],
#   'type': 'StormLeague'},
#  {'first': ['Garrosh', 'Imperius', 'Chromie', 'Tychus', 'Brightwing'],
#   'first_won': True,
#   'map': 'Tomb of the Spider Queen',
#   'second': ['Mephisto', 'Anduin', 'E.T.C.', 'Zagara', 'Orphea'],
#   'type': 'StormLeague'},
#  {'first': ['Greymane', 'Rexxar', 'Rehgar', 'E.T.C.', "Zul'jin"],
#   'first_won': True,
#   'map': 'Battlefield of Eternity',
#   'second': ['Johanna', 'Ana', 'Kerrigan', 'Fenix', 'Tychus'],
#   'type': 'StormLeague'},
#  {'first': ['Tassadar', 'Arthas', 'Auriel', 'Sonya', 'The Butcher'],
#   'first_won': True,
#   'map': 'Alterac Pass',
#   'second': ['Abathur', "Kael'thas", 'Tyrande', 'Hanzo', "Anub'arak"],
#   'type': 'StormLeague'},
#  {'first': ['Abathur', 'D.Va', 'Muradin', 'Rehgar', 'Raynor'],
#   'first_won': True,
#   'map': 'Volskaya Foundry',
#   'second': ['Diablo', 'Stukov', 'Jaina', 'Fenix', 'Deathwing'],
#   'type': 'StormLeague'},
#  {'first': ['Mei', 'Li Li', 'Raynor', 'Maiev', 'Artanis'],
#   'first_won': True,
#   'map': 'Volskaya Foundry',
#   'second': ['Gazlowe', 'Lúcio', 'Arthas', 'Samuro', 'Stitches'],
#   'type': 'StormLeague'},
#  {'first': ['Rehgar', 'Tassadar', 'Diablo', 'Samuro', 'Uther'],
#   'first_won': True,
#   'map': 'Garden of Terror',
#   'second': ['Johanna', 'Greymane', 'Cassia', 'Li Li', 'Deathwing'],
#   'type': 'StormLeague'},
#  {'first': ['Brightwing', 'Sonya', 'Diablo', 'Tassadar', 'Hanzo'],
#   'first_won': False,
#   'map': 'Infernal Shrines',
#   'second': ['The Lost Vikings', 'Stukov', 'Greymane', 'E.T.C.', 'Tychus'],
#   'type': 'StormLeague'},
#  {'first': ['Li-Ming', 'Zeratul', 'E.T.C.', 'Genji', 'Brightwing'],
#   'first_won': False,
#   'map': 'Cursed Hollow',
#   'second': ['Ana', 'Muradin', 'Tassadar', "Anub'arak", 'Valeera'],
#   'type': 'StormLeague'},
#  {'first': ["Mal'Ganis", 'Alarak', 'Li-Ming', 'Li Li', 'Sylvanas'],
#   'first_won': False,
#   'map': 'Dragon Shire',
#   'second': ['Raynor', 'Muradin', 'Tracer', 'Anduin', 'Sonya'],
#   'type': 'StormLeague'},
#  {'first': ['Gazlowe', 'Imperius', 'Brightwing', 'Sylvanas', 'Li-Ming'],
#   'first_won': False,
#   'map': 'Volskaya Foundry',
#   'second': ['Maiev', 'Muradin', 'D.Va', 'Raynor', 'Lúcio'],
#   'type': 'StormLeague'},
#  {'first': ['Raynor', 'Varian', 'Deckard', 'Samuro', 'Li-Ming'],
#   'first_won': True,
#   'map': 'Garden of Terror',
#   'second': ['Diablo', 'Tassadar', 'Uther', 'Zagara', 'Sonya'],
#   'type': 'StormLeague'},
#  {'first': ['Abathur', 'Azmodan', 'Muradin', 'Li Li', 'Samuro'],
#   'first_won': False,
#   'map': 'Cursed Hollow',
#   'second': ['Brightwing', 'Greymane', 'Tychus', 'Imperius', 'Diablo'],
#   'type': 'StormLeague'},
#  {'first': ['Li-Ming', 'Deckard', 'Sylvanas', 'Varian', 'Imperius'],
#   'first_won': False,
#   'map': 'Sky Temple',
#   'second': ['Stukov', 'Leoric', 'Malthael', 'Thrall', 'Arthas'],
#   'type': 'StormLeague'},
#  {'first': ['Alexstrasza', 'Dehaka', 'Arthas', 'Kerrigan', 'Tassadar'],
#   'first_won': False,
#   'map': 'Garden of Terror',
#   'second': ['Cassia', 'E.T.C.', 'Whitemane', 'Ragnaros', "Kael'thas"],
#   'type': 'StormLeague'},
#  {'first': ['Artanis', 'Brightwing', "Kael'thas", 'Garrosh', 'Sylvanas'],
#   'first_won': False,
#   'map': 'Towers of Doom',
#   'second': ['Mei', 'Tychus', 'Li Li', 'Jaina', 'Rexxar'],
#   'type': 'StormLeague'},
#  {'first': ['Medivh', 'Brightwing', 'Cassia', 'Sonya', 'Mei'],
#   'first_won': True,
#   'map': 'Garden of Terror',
#   'second': ["Kel'Thuzad", 'Hanzo', 'Stukov', 'Johanna', 'Dehaka'],
#   'type': 'StormLeague'},
#  {'first': ['Mei', 'Tyrande', 'Leoric', 'Medivh', 'Raynor'],
#   'first_won': True,
#   'map': 'Towers of Doom',
#   'second': ['Garrosh', "Zul'jin", 'Ana', 'Murky', 'Thrall'],
#   'type': 'StormLeague'},
#  {'first': ['Hanzo', 'Muradin', 'Sonya', 'Tyrande', 'Lunara'],
#   'first_won': True,
#   'map': 'Battlefield of Eternity',
#   'second': ['Imperius', 'Valla', "Kael'thas", 'Diablo', 'Rehgar'],
#   'type': 'StormLeague'},
#  {'first': ['Cassia', 'Garrosh', 'Uther', 'Illidan', 'Leoric'],
#   'first_won': False,
#   'map': 'Garden of Terror',
#   'second': ['Diablo', 'Ana', 'Li-Ming', 'Greymane', 'Xul'],
#   'type': 'StormLeague'},
#  {'first': ['D.Va', 'Brightwing', 'Blaze', 'Li-Ming', 'Tychus'],
#   'first_won': False,
#   'map': 'Hanamura Temple',
#   'second': ['Greymane', 'Johanna', 'Jaina', 'Deathwing', 'Malfurion'],
#   'type': 'StormLeague'},
#  {'first': ['Gazlowe', 'Greymane', 'Cho', 'Gall', 'Auriel'],
#   'first_won': True,
#   'map': 'Alterac Pass',
#   'second': ['Muradin', 'Alexstrasza', 'The Lost Vikings', 'Hanzo', 'Tychus'],
#   'type': 'StormLeague'},
#  {'first': ['Xul', "Gul'dan", 'Muradin', 'Brightwing', 'Greymane'],
#   'first_won': True,
#   'map': 'Infernal Shrines',
#   'second': ['Li-Ming', "Mal'Ganis", 'Thrall', 'Valeera', 'Zagara'],
#   'type': 'StormLeague'},
#  {'first': ['D.Va', 'Jaina', 'Rehgar', 'Deathwing', 'Valla'],
#   'first_won': True,
#   'map': 'Infernal Shrines',
#   'second': ['Brightwing', 'Diablo', 'Raynor', 'Nazeebo', 'Malthael'],
#   'type': 'StormLeague'},
#  {'first': ['Cassia', 'Stitches', "Kael'thas", 'Deathwing', 'Malfurion'],
#   'first_won': False,
#   'map': 'Braxis Holdout',
#   'second': ['Deckard', "Mal'Ganis", 'Lunara', 'Yrel', 'Tassadar'],
#   'type': 'StormLeague'},
#  {'first': ['Brightwing', 'Mei', "Kel'Thuzad", 'Tassadar', 'Maiev'],
#   'first_won': True,
#   'map': 'Volskaya Foundry',
#   'second': ['Cassia', 'Johanna', 'Deckard', 'Blaze', 'Hanzo'],
#   'type': 'StormLeague'},
#  {'first': ['Muradin', 'Anduin', 'Junkrat', 'Ragnaros', 'Greymane'],
#   'first_won': False,
#   'map': 'Infernal Shrines',
#   'second': ['Auriel', 'Diablo', 'Orphea', 'Raynor', 'Varian'],
#   'type': 'StormLeague'},
#  {'first': ['Nazeebo', 'Hanzo', 'Imperius', 'Stukov', 'Muradin'],
#   'first_won': False,
#   'map': 'Alterac Pass',
#   'second': ['Brightwing', 'E.T.C.', 'Jaina', 'Tychus', 'Samuro'],
#   'type': 'StormLeague'},
#  {'first': ['Valla', 'Stukov', "Kel'Thuzad", 'Imperius', 'Stitches'],
#   'first_won': True,
#   'map': 'Braxis Holdout',
#   'second': ['Mephisto', 'Diablo', 'Ana', 'Tychus', 'Thrall'],
#   'type': 'StormLeague'},
#  {'first': ['Nazeebo', 'Lunara', 'Muradin', 'Deckard', 'Greymane'],
#   'first_won': False,
#   'map': 'Tomb of the Spider Queen',
#   'second': ['Jaina', 'Johanna', 'Sylvanas', 'Li Li', 'Sonya'],
#   'type': 'StormLeague'},
#  {'first': ['Mei', 'Brightwing', 'Sonya', "Kael'thas", 'Sylvanas'],
#   'first_won': False,
#   'map': 'Dragon Shire',
#   'second': ['Samuro', 'Uther', 'Falstad', 'Deathwing', 'Chromie'],
#   'type': 'StormLeague'},
#  {'first': ['Chen', 'Sylvanas', 'Tyrande', 'Diablo', 'Greymane'],
#   'first_won': False,
#   'map': 'Cursed Hollow',
#   'second': ['Gazlowe', 'Tassadar', 'Rehgar', 'Muradin', 'Orphea'],
#   'type': 'StormLeague'},
#  {'first': ['Valla', 'Sonya', 'Whitemane', 'Arthas', 'Zeratul'],
#   'first_won': False,
#   'map': 'Hanamura Temple',
#   'second': ['Ragnaros', 'Johanna', 'Brightwing', 'Greymane', 'Jaina'],
#   'type': 'StormLeague'},
#  {'first': ['Greymane', 'Alexstrasza', 'Maiev', 'Qhira', 'Johanna'],
#   'first_won': False,
#   'map': 'Braxis Holdout',
#   'second': ['Stukov', 'Sylvanas', 'Mei', 'Tassadar', 'Lunara'],
#   'type': 'StormLeague'},
#  {'first': ['Cassia', 'Diablo', 'Tassadar', 'Uther', 'Rexxar'],
#   'first_won': True,
#   'map': 'Sky Temple',
#   'second': ['Brightwing', 'Kerrigan', 'Johanna', 'Blaze', 'Azmodan'],
#   'type': 'StormLeague'},
#  {'first': ['Artanis', 'Li-Ming', 'Rehgar', 'Mei', 'Sgt. Hammer'],
#   'first_won': True,
#   'map': 'Towers of Doom',
#   'second': ['Muradin', 'Lunara', 'Anduin', 'Malthael', "Gul'dan"],
#   'type': 'StormLeague'},
#  {'first': ['Garrosh', 'Tyrande', "Zul'jin", 'Tychus', 'Li Li'],
#   'first_won': False,
#   'map': 'Hanamura Temple',
#   'second': ['Anduin', 'Artanis', 'Diablo', 'Genji', 'Chromie'],
#   'type': 'StormLeague'},
#  {'first': ['Artanis', 'Li-Ming', 'Rehgar', 'Muradin', 'Falstad'],
#   'first_won': True,
#   'map': 'Battlefield of Eternity',
#   'second': ['Li Li', 'Johanna', 'Lunara', 'Leoric', 'Genji'],
#   'type': 'StormLeague'},
#  {'first': ["Kael'thas", 'E.T.C.', 'Murky', 'Auriel', 'Artanis'],
#   'first_won': True,
#   'map': 'Infernal Shrines',
#   'second': ['Mei', 'Falstad', 'Tyrande', 'Fenix', 'Dehaka'],
#   'type': 'StormLeague'},
#  {'first': ['Li-Ming', 'Garrosh', 'Malfurion', 'Tychus', 'Sonya'],
#   'first_won': False,
#   'map': 'Hanamura Temple',
#   'second': ['Raynor', 'Li Li', 'Johanna', 'Nazeebo', 'Dehaka'],
#   'type': 'StormLeague'},
#  {'first': ['Cassia', 'Brightwing', 'Xul', 'Johanna', 'Li-Ming'],
#   'first_won': True,
#   'map': 'Towers of Doom',
#   'second': ['Abathur', 'Illidan', 'Diablo', 'Malthael', 'Lúcio'],
#   'type': 'StormLeague'},
#  {'first': ['Mei', 'Artanis', 'Li Li', 'Raynor', 'Falstad'],
#   'first_won': True,
#   'map': 'Hanamura Temple',
#   'second': ['Li-Ming', 'Rehgar', 'Yrel', 'Johanna', "Zul'jin"],
#   'type': 'StormLeague'},
#  {'first': ['Sonya', 'Cassia', "Kael'thas", 'Johanna', 'Li Li'],
#   'first_won': False,
#   'map': 'Infernal Shrines',
#   'second': ['Varian', 'Tassadar', 'Tyrande', 'Kerrigan', 'Zarya'],
#   'type': 'StormLeague'},
#  {'first': ['Orphea', 'Ragnaros', 'Nova', 'Abathur', 'Zeratul'],
#   'first_won': True,
#   'map': 'Garden of Terror',
#   'second': ['Tyrande', 'Raynor', 'Imperius', 'Nazeebo', 'Muradin'],
#   'type': 'StormLeague'},
#  {'first': ['Diablo', 'Cassia', 'Alexstrasza', 'Varian', 'Orphea'],
#   'first_won': False,
#   'map': 'Volskaya Foundry',
#   'second': ['Li-Ming', 'Kharazim', 'Tychus', 'Deathwing', 'Mei'],
#   'type': 'StormLeague'},
#  {'first': ['Jaina', 'Hanzo', 'E.T.C.', 'Li Li', 'Sonya'],
#   'first_won': False,
#   'map': 'Hanamura Temple',
#   'second': ['Li-Ming', 'Chen', 'Muradin', 'Stukov', 'Nova'],
#   'type': 'StormLeague'},
#  {'first': ['Sonya', 'Li-Ming', 'Mei', 'Azmodan', 'Anduin'],
#   'first_won': True,
#   'map': 'Hanamura Temple',
#   'second': ['Diablo', 'Thrall', 'Lt. Morales', 'Mephisto', 'Maiev'],
#   'type': 'StormLeague'},
#  {'first': ['Mei', 'Valla', 'Ana', 'Varian', 'Cassia'],
#   'first_won': False,
#   'map': 'Tomb of the Spider Queen',
#   'second': ['D.Va', 'Nazeebo', 'Sylvanas', 'Uther', 'Johanna'],
#   'type': 'StormLeague'},
#  {'first': ['Diablo', 'Tassadar', 'Imperius', 'Brightwing', 'Sgt. Hammer'],
#   'first_won': False,
#   'map': 'Towers of Doom',
#   'second': ['Xul', 'Tyrande', 'Garrosh', 'Greymane', 'Li-Ming'],
#   'type': 'StormLeague'},
#  {'first': ['Mephisto', 'Stukov', 'Diablo', 'Junkrat', 'Thrall'],
#   'first_won': False,
#   'map': 'Volskaya Foundry',
#   'second': ['Johanna', 'Brightwing', 'Cassia', 'Yrel', "Gul'dan"],
#   'type': 'StormLeague'},
#  {'first': ['Tassadar', 'Sylvanas', 'Artanis', 'Malfurion', 'Blaze'],
#   'first_won': True,
#   'map': 'Hanamura Temple',
#   'second': ['Junkrat', 'Stukov', 'Varian', 'Malthael', "Zul'jin"],
#   'type': 'StormLeague'},
#  {'first': ['Gazlowe', 'Li-Ming', 'Lunara', 'Brightwing', 'Diablo'],
#   'first_won': False,
#   'map': 'Cursed Hollow',
#   'second': ['Valla', 'Whitemane', 'Muradin', 'The Lost Vikings', 'Samuro'],
#   'type': 'StormLeague'},
#  {'first': ['Brightwing', 'E.T.C.', 'Xul', 'Falstad', 'Raynor'],
#   'first_won': False,
#   'map': 'Sky Temple',
#   'second': ['Gazlowe', "Kael'thas", 'Alexstrasza', "Anub'arak", 'D.Va'],
#   'type': 'StormLeague'},
#  {'first': ['D.Va', 'Whitemane', "Zul'jin", 'Tassadar', 'Muradin'],
#   'first_won': False,
#   'map': 'Infernal Shrines',
#   'second': ['Stukov', 'Sonya', 'Diablo', 'Tracer', 'Greymane'],
#   'type': 'StormLeague'},
#  {'first': ['Varian', 'Jaina', 'Malfurion', 'Falstad', 'Deathwing'],
#   'first_won': True,
#   'map': 'Cursed Hollow',
#   'second': ['D.Va', 'Garrosh', 'Zeratul', 'Genji', 'Whitemane'],
#   'type': 'StormLeague'},
#  {'first': ["Kael'thas", 'Deckard', 'Raynor', 'Johanna', 'Imperius'],
#   'first_won': False,
#   'map': 'Hanamura Temple',
#   'second': ['Mei', 'Li-Ming', 'Auriel', 'Sonya', 'Tracer'],
#   'type': 'StormLeague'},
#  {'first': ['Cassia', 'Rehgar', 'Tassadar', 'Leoric', 'Varian'],
#   'first_won': True,
#   'map': 'Tomb of the Spider Queen',
#   'second': ['Malfurion', "Anub'arak", 'Imperius', 'Kerrigan', 'Orphea'],
#   'type': 'StormLeague'},
#  {'first': ['Sylvanas', 'Stukov', 'Diablo', 'Blaze', 'Nazeebo'],
#   'first_won': True,
#   'map': 'Tomb of the Spider Queen',
#   'second': ['D.Va', 'Stitches', 'Uther', 'Tassadar', 'Greymane'],
#   'type': 'StormLeague'},
#  {'first': ['Mei', 'Li-Ming', 'Raynor', 'Artanis', 'Lt. Morales'],
#   'first_won': True,
#   'map': 'Tomb of the Spider Queen',
#   'second': ['Abathur', 'Kharazim', 'Tassadar', 'Hanzo', 'E.T.C.'],
#   'type': 'StormLeague'},
#  {'first': ["Kael'thas", 'Malthael', 'Garrosh', 'Li Li', 'Raynor'],
#   'first_won': False,
#   'map': 'Sky Temple',
#   'second': ['E.T.C.', 'Anduin', 'Greymane', "Kel'Thuzad", 'Imperius'],
#   'type': 'StormLeague'},
#  {'first': ['Greymane', 'Johanna', 'Leoric', 'Alexstrasza', 'Jaina'],
#   'first_won': False,
#   'map': 'Battlefield of Eternity',
#   'second': ['Mei', 'Valla', 'Li-Ming', 'Thrall', 'Li Li'],
#   'type': 'StormLeague'},
#  {'first': ['Li-Ming', 'Ana', 'Stitches', 'Valla', 'Dehaka'],
#   'first_won': False,
#   'map': 'Infernal Shrines',
#   'second': ['Greymane', 'E.T.C.', 'Sylvanas', 'Sonya', 'Deckard'],
#   'type': 'StormLeague'},
#  {'first': ['Junkrat', 'Brightwing', 'Muradin', 'Sylvanas', 'Deathwing'],
#   'first_won': True,
#   'map': 'Infernal Shrines',
#   'second': ['Medivh', 'Ana', 'Johanna', 'Imperius', 'Sgt. Hammer'],
#   'type': 'StormLeague'},
#  {'first': ['Greymane', 'Ragnaros', 'Ana', 'Jaina', 'Tyrael'],
#   'first_won': True,
#   'map': 'Sky Temple',
#   'second': ["Kael'thas", 'Samuro', 'Johanna', 'Stukov', 'Raynor'],
#   'type': 'StormLeague'},
#  {'first': ['Sylvanas', 'Muradin', 'Cassia', "Kael'thas", 'Deckard'],
#   'first_won': False,
#   'map': 'Infernal Shrines',
#   'second': ['Tassadar', 'Junkrat', 'Tyrande', 'Varian', 'Leoric'],
#   'type': 'StormLeague'},
#  {'first': ['Muradin', 'Tyrande', 'Varian', 'Azmodan', 'Tracer'],
#   'first_won': False,
#   'map': 'Cursed Hollow',
#   'second': ['The Lost Vikings',
#              "Kael'thas",
#              'Lt. Morales',
#              'Arthas',
#              'Alarak'],
#   'type': 'StormLeague'},
#  {'first': ['Raynor', 'Diablo', 'Anduin', 'Malthael', 'Nova'],
#   'first_won': True,
#   'map': 'Battlefield of Eternity',
#   'second': ['Rehgar', 'Orphea', 'Leoric', 'Muradin', 'Lunara'],
#   'type': 'StormLeague'},
#  {'first': ['Valla', 'Varian', 'Muradin', 'Rehgar', 'Tassadar'],
#   'first_won': True,
#   'map': 'Battlefield of Eternity',
#   'second': ['D.Va', 'Imperius', 'Raynor', 'Stukov', 'Arthas'],
#   'type': 'StormLeague'},
#  {'first': ['Mei', 'Lúcio', 'Tracer', 'Jaina', 'Artanis'],
#   'first_won': False,
#   'map': 'Alterac Pass',
#   'second': ['Muradin', 'Uther', 'Abathur', "Gul'dan", 'Illidan'],
#   'type': 'StormLeague'},
#  {'first': ['Thrall', 'Ana', 'Malthael', 'The Lost Vikings', "Anub'arak"],
#   'first_won': True,
#   'map': 'Cursed Hollow',
#   'second': ['Dehaka', 'Garrosh', 'Genji', 'Whitemane', 'Li-Ming'],
#   'type': 'StormLeague'},
#  {'first': ['Lunara', 'Imperius', "Kel'Thuzad", 'Alexstrasza', 'Artanis'],
#   'first_won': False,
#   'map': 'Battlefield of Eternity',
#   'second': ['Valla', 'Medivh', 'Malthael', 'Stitches', "Zul'jin"],
#   'type': 'StormLeague'},
#  {'first': ['D.Va', 'Brightwing', 'Mei', 'Chromie', 'Sylvanas'],
#   'first_won': True,
#   'map': 'Sky Temple',
#   'second': ['Rexxar', 'Cassia', 'Greymane', 'Varian', 'Li Li'],
#   'type': 'StormLeague'},
#  {'first': ['Greymane', 'Anduin', 'Yrel', 'Arthas', 'Uther'],
#   'first_won': False,
#   'map': 'Towers of Doom',
#   'second': ['Brightwing', 'Li-Ming', 'Illidan', 'Mei', 'Abathur'],
#   'type': 'StormLeague'},
#  {'first': ['Tychus', 'Hanzo', "Anub'arak", 'Anduin', 'Leoric'],
#   'first_won': False,
#   'map': 'Sky Temple',
#   'second': ['Brightwing', 'Mephisto', 'Johanna', 'Artanis', 'Raynor'],
#   'type': 'StormLeague'},
#  {'first': ['D.Va', 'Anduin', 'Johanna', 'Cassia', 'Nazeebo'],
#   'first_won': True,
#   'map': 'Tomb of the Spider Queen',
#   'second': ['Tassadar', 'Arthas', 'Zeratul', 'Brightwing', 'Tychus'],
#   'type': 'StormLeague'},
#  {'first': ['Deckard', 'Jaina', 'Johanna', 'The Butcher', 'Greymane'],
#   'first_won': True,
#   'map': 'Tomb of the Spider Queen',
#   'second': ['D.Va', 'Chromie', 'Valla', 'Brightwing', 'Muradin'],
#   'type': 'StormLeague'}]

# %%
game=raw_data[1]
first_team=[]
second_team=[]
for player in game["players"]:
        if game["players"][player]["team"]==0:
            first_team.append(game["players"][player]["hero"])
        else:
            second_team.append(game["players"][player]["hero"])
print(first_team)
print(second_team)
# Out:
# ['Nazeebo', 'Ana', 'Valla', 'Johanna', 'Imperius']
# ['Muradin', 'Raynor', 'Artanis', "Gul'dan", 'Auriel']
