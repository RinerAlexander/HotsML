# %%
import requests
import json
from pprint import pprint
import re
url = "http://hotsapi.net/api/v1/replays?min_id=31000000&existing=true&with_players=true"
raw_data=requests.get(url).json()
pprint(raw_data)
# Out:
# [{'bans': None,
#   'created_at': '2021-03-05 16:29:50',
#   'deleted': False,
#   'filename': '52d2016c-e937-ab16-64fc-fa54aaa1d0d8',
#   'fingerprint': '52d2016c-e937-ab16-64fc-fa54aaa1d0d8',
#   'game_date': '2021-02-02 18:52:52',
#   'game_length': 1742,
#   'game_map': 'Garden of Terror',
#   'game_type': 'QuickMatch',
#   'game_version': '2.53.1.83716',
#   'id': 31000000,
#   'parsed_id': 26154458,
#   'players': {'0': {'battletag': 'ReVeNGe#2956',
#                     'blizz_id': 419046,
#                     'hero': 'Valeera',
#                     'hero_level': 20,
#                     'party': 0,
#                     'score': {'assists': 18,
#                               'clutch_heals_performed': 0,
#                               'creep_damage': 2870,
#                               'damage_soaked': 29751,
#                               'damage_taken': 64394,
#                               'deaths': 8,
#                               'escapes_performed': 2,
# ...
